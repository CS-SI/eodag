# %% [markdown]
# # Crunch

# %% [markdown]
# Crunching as defined in `eodag` is a way to filter the EO products contained in a [SearchResult](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult) object. Several filters are available and further described in this document.

# %% [markdown]
# A [SearchResult](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult) has a [crunch()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.crunch) method that requires a filter instance as an argument, itself initialized with a dictionary that contains the required parameters. According to the filter used, some more kwargs may need to be passed to [crunch()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.crunch). The filters return a `list` of [EOProduct](../../api_reference/eoproduct.rst#eodag.api.product._product.EOProduct)s.

# %% [markdown]
# You will learn how to:
# - [Setup](#Setup)
# - [Filter by start and end date](#Filter-by-start-and-end-date)
# - [Filter by geometry](#Filter-by-geometry)
# - [Filter by property](#Filter-by-property)
# - [Filter for online products](#Filter-for-online-products)
# - [Filter the latest products intersecting a geometry](#Filter-the-latest-products-intersecting-a-geometry)

# %% [markdown]
# ## Setup

# %% [markdown]
# Results obtained from a search of *Sentinel 2 Level-1C* products over France in March 2021 are loaded in a [SearchResult](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult).

# %%
from eodag import EODataAccessGateway
dag = EODataAccessGateway()
search_results = dag.deserialize("data/crunch_search_results.geojson")
print(f"This SearchResult stores {len(search_results)} products.")
# Out:
# This SearchResult stores 50 products.

# %%
# This code cell has a special metadata entry: "nbsphinx": "hidden"
# That hides it when the documentation is built with nbsphinx/sphinx.

# Uncomment these lines to regenerate the GeoJSON file used in this notebook.

# search_results = dag.search(
#    collection="S2_MSI_L1C",
#    start="2021-03-01",
#    end="2021-03-31",
#    geom={"lonmin": 1, "latmin": 45, "lonmax": 5, "latmax": 47},
#    items_per_page=50
# )
# dag.serialize(search_results, "data/crunch_search_results.geojson")

# %% [markdown]
# The original search geometry is used throughout the notebook as long as with its representation as a a `shapely` object which is easier to map with `folium`.

# %%
original_search_geometry = {"lonmin": 1, "latmin": 45, "lonmax": 5, "latmax": 47}

# %%
import shapely

search_geometry = shapely.geometry.box(
    original_search_geometry["lonmin"],
    original_search_geometry["latmin"],
    original_search_geometry["lonmax"],
    original_search_geometry["latmax"],
)

# %%
# To create interactive maps
import folium

def create_search_result_map(search_results, extent):
    """Small utility to create an interactive map with folium
    that displays an extent in red and EO Producs in blue"""
    fmap = folium.Map([46, 3], zoom_start=6)
    folium.GeoJson(
        extent,
        style_function=lambda x: dict(color="red")
    ).add_to(fmap)
    folium.GeoJson(
        search_results
    ).add_to(fmap)
    return fmap

# %% [markdown]
# ## Filter by start and end date

# %% [markdown]
# [FilterDate](../../plugins_reference/generated/eodag.plugins.crunch.filter_date.FilterDate.rst#eodag.plugins.crunch.filter_date.FilterDate) allows to filter out products that are older than a start date (optional) or more recent than an end date (optional).
#
# > This cruncher can also be called directly using  [SearchResult.filter_date()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.filter_date).

# %%
from eodag.crunch import FilterDate

# %%
filtered_products = search_results.crunch(
    FilterDate(dict(start="2021-03-25", end="2021-03-29"))
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the date filter.")
# Out:
# 21 products were filtered out by the date filter.

# %% [markdown]
# ## Filter by geometry

# %% [markdown]
# [FilterOverlap](../../plugins_reference/generated/eodag.plugins.crunch.filter_overlap.FilterOverlap.rst#eodag.plugins.crunch.filter_overlap.FilterOverlap) allows to filter out products that:
#
# * whose overlap area with a geometry is less than a percentage of their area
# * are not *within* a geometry
# * do not *contain* a geometry
# * do not *intersect* with a geometry
#
# To execute a [FilterOverlap](../../plugins_reference/generated/eodag.plugins.crunch.filter_overlap.FilterOverlap.rst#eodag.plugins.crunch.filter_overlap.FilterOverlap), its instance must be created by passing a dictionary with either:
#
# * `minimum_overlap` set to a number between 0 and 100. `within`, `contains` and `intersects` cannot be used in that case.
# * **One** of `within`, `contains` and `intersects` (they are mutually exclusive) set to True. `minimum_overlap` cannot be used in that case.
#
# Additionally, a geometry (shapely geometry, bounding box as a dictionary or a list) must be passed through the `geometry` parameter.
#
# The examples below show how [FilterOverlap](../../plugins_reference/generated/eodag.plugins.crunch.filter_overlap.FilterOverlap.rst#eodag.plugins.crunch.filter_overlap.FilterOverlap) filter out products. The original products will be displayed in blue and the filtered products in green.
#
# > This cruncher can also be called directly using [SearchResult.filter_overlap()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.filter_overlap).

# %%
from eodag.crunch import FilterOverlap

# %% [markdown]
# All the products are displayed on the next map. As it can be observed, they all intersect with the search geometry.

# %%
create_search_result_map(search_results, search_geometry)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0983c0c3480bb506e8b15df5482229e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0983c0c3480bb506e8b15df5482229e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0983c0c3480bb506e8b15df5482229e7 = L.map(
#                 &quot;map_0983c0c3480bb506e8b15df5482229e7&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abdfb8cb4448a0a67029b4e3be3c60f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abdfb8cb4448a0a67029b4e3be3c60f3.addTo(map_0983c0c3480bb506e8b15df5482229e7);
#
#
#         function geo_json_1647d3541a97367bf0914181e04b45ed_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_1647d3541a97367bf0914181e04b45ed_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1647d3541a97367bf0914181e04b45ed = L.geoJson(null, {
#                 onEachFeature: geo_json_1647d3541a97367bf0914181e04b45ed_onEachFeature,
#
#                 style: geo_json_1647d3541a97367bf0914181e04b45ed_styler,
#             ...{
# }
#         });
#
#         function geo_json_1647d3541a97367bf0914181e04b45ed_add (data) {
#             geo_json_1647d3541a97367bf0914181e04b45ed
#                 .addData(data);
#         }
#             geo_json_1647d3541a97367bf0914181e04b45ed_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.0, 45.0], [5.0, 47.0], [1.0, 47.0], [1.0, 45.0], [5.0, 45.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_1647d3541a97367bf0914181e04b45ed.addTo(map_0983c0c3480bb506e8b15df5482229e7);
#
#
#
#         function geo_json_4e494e310922d6ba19ff6e84c3ed8793_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4e494e310922d6ba19ff6e84c3ed8793 = L.geoJson(null, {
#                 onEachFeature: geo_json_4e494e310922d6ba19ff6e84c3ed8793_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4e494e310922d6ba19ff6e84c3ed8793_add (data) {
#             geo_json_4e494e310922d6ba19ff6e84c3ed8793
#                 .addData(data);
#         }
#             geo_json_4e494e310922d6ba19ff6e84c3ed8793_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &quot;peps:isN

# %% [markdown]
# The next two examples show how `minimum_overlap` affects the filter, with its value (i.e. percentage) set to 10 and 50%.

# %%
filtered_products = search_results.crunch(
    FilterOverlap(dict(minimum_overlap=10)),
    geometry=search_geometry
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the geometry filter.")
# Out:
# 18 products were filtered out by the geometry filter.

# %%
fmap = create_search_result_map(search_results, search_geometry)
# Create a layer that represents the search area in green
folium.GeoJson(
    filtered_products,
    style_function=lambda x: dict(color="green")
).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8111b690dd3c6c299fb5195d44dd2075 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8111b690dd3c6c299fb5195d44dd2075&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8111b690dd3c6c299fb5195d44dd2075 = L.map(
#                 &quot;map_8111b690dd3c6c299fb5195d44dd2075&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c0558c23e2c0bf64f04b6e8e86d4e93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c0558c23e2c0bf64f04b6e8e86d4e93.addTo(map_8111b690dd3c6c299fb5195d44dd2075);
#
#
#         function geo_json_0aca171262b1420adcc53e0f280140f5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_0aca171262b1420adcc53e0f280140f5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0aca171262b1420adcc53e0f280140f5 = L.geoJson(null, {
#                 onEachFeature: geo_json_0aca171262b1420adcc53e0f280140f5_onEachFeature,
#
#                 style: geo_json_0aca171262b1420adcc53e0f280140f5_styler,
#             ...{
# }
#         });
#
#         function geo_json_0aca171262b1420adcc53e0f280140f5_add (data) {
#             geo_json_0aca171262b1420adcc53e0f280140f5
#                 .addData(data);
#         }
#             geo_json_0aca171262b1420adcc53e0f280140f5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.0, 45.0], [5.0, 47.0], [1.0, 47.0], [1.0, 45.0], [5.0, 45.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_0aca171262b1420adcc53e0f280140f5.addTo(map_8111b690dd3c6c299fb5195d44dd2075);
#
#
#
#         function geo_json_3a557541e4f3d1c148f216cdcab244df_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3a557541e4f3d1c148f216cdcab244df = L.geoJson(null, {
#                 onEachFeature: geo_json_3a557541e4f3d1c148f216cdcab244df_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_3a557541e4f3d1c148f216cdcab244df_add (data) {
#             geo_json_3a557541e4f3d1c148f216cdcab244df
#                 .addData(data);
#         }
#             geo_json_3a557541e4f3d1c148f216cdcab244df_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &quot;peps:isN

# %%
filtered_products = search_results.crunch(
    FilterOverlap(dict(minimum_overlap=50)),
    geometry=search_geometry
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the geometry filter.")
# Out:
# 35 products were filtered out by the geometry filter.

# %%
fmap = create_search_result_map(search_results, search_geometry)
# Create a layer that represents the search area in green
folium.GeoJson(
    filtered_products,
    style_function=lambda x: dict(color="green")
).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d6577bd835c2e0c087e3936b219243c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d6577bd835c2e0c087e3936b219243c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d6577bd835c2e0c087e3936b219243c = L.map(
#                 &quot;map_5d6577bd835c2e0c087e3936b219243c&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5c6e93609f359505557e5a46aa60245 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5c6e93609f359505557e5a46aa60245.addTo(map_5d6577bd835c2e0c087e3936b219243c);
#
#
#         function geo_json_6ddd8e82b947fbbc079f5eeee303bb3c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_6ddd8e82b947fbbc079f5eeee303bb3c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6ddd8e82b947fbbc079f5eeee303bb3c = L.geoJson(null, {
#                 onEachFeature: geo_json_6ddd8e82b947fbbc079f5eeee303bb3c_onEachFeature,
#
#                 style: geo_json_6ddd8e82b947fbbc079f5eeee303bb3c_styler,
#             ...{
# }
#         });
#
#         function geo_json_6ddd8e82b947fbbc079f5eeee303bb3c_add (data) {
#             geo_json_6ddd8e82b947fbbc079f5eeee303bb3c
#                 .addData(data);
#         }
#             geo_json_6ddd8e82b947fbbc079f5eeee303bb3c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.0, 45.0], [5.0, 47.0], [1.0, 47.0], [1.0, 45.0], [5.0, 45.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_6ddd8e82b947fbbc079f5eeee303bb3c.addTo(map_5d6577bd835c2e0c087e3936b219243c);
#
#
#
#         function geo_json_1e79c5a5d24c9d34d3cdc6730b84ffc7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1e79c5a5d24c9d34d3cdc6730b84ffc7 = L.geoJson(null, {
#                 onEachFeature: geo_json_1e79c5a5d24c9d34d3cdc6730b84ffc7_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_1e79c5a5d24c9d34d3cdc6730b84ffc7_add (data) {
#             geo_json_1e79c5a5d24c9d34d3cdc6730b84ffc7
#                 .addData(data);
#         }
#             geo_json_1e79c5a5d24c9d34d3cdc6730b84ffc7_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &quot;peps:isN

# %% [markdown]
# More and more products are filtered out when `minimum_overlap` increases. The next parameter given as an example is `within`, it is actually equivalent to setting `minimum_overlap` to 100.

# %%
filtered_products = search_results.crunch(
    FilterOverlap(dict(within=True)),
    geometry=search_geometry
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the geometry filter.")
# Out:
# 38 products were filtered out by the geometry filter.

# %%
fmap = create_search_result_map(search_results, search_geometry)
# Create a layer that represents the filtered products in green
folium.GeoJson(
    filtered_products,
    style_function=lambda x: dict(color="green")
).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42070bb575cd5a35b84e21c7129e2b5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42070bb575cd5a35b84e21c7129e2b5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42070bb575cd5a35b84e21c7129e2b5f = L.map(
#                 &quot;map_42070bb575cd5a35b84e21c7129e2b5f&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_661da97c0bdb5c98a4cd19e14808f237 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_661da97c0bdb5c98a4cd19e14808f237.addTo(map_42070bb575cd5a35b84e21c7129e2b5f);
#
#
#         function geo_json_94e3bc76832c394bfe7e86472e32239e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_94e3bc76832c394bfe7e86472e32239e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_94e3bc76832c394bfe7e86472e32239e = L.geoJson(null, {
#                 onEachFeature: geo_json_94e3bc76832c394bfe7e86472e32239e_onEachFeature,
#
#                 style: geo_json_94e3bc76832c394bfe7e86472e32239e_styler,
#             ...{
# }
#         });
#
#         function geo_json_94e3bc76832c394bfe7e86472e32239e_add (data) {
#             geo_json_94e3bc76832c394bfe7e86472e32239e
#                 .addData(data);
#         }
#             geo_json_94e3bc76832c394bfe7e86472e32239e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.0, 45.0], [5.0, 47.0], [1.0, 47.0], [1.0, 45.0], [5.0, 45.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_94e3bc76832c394bfe7e86472e32239e.addTo(map_42070bb575cd5a35b84e21c7129e2b5f);
#
#
#
#         function geo_json_d645fcda39d4bea06e1fee89f2ac38f2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d645fcda39d4bea06e1fee89f2ac38f2 = L.geoJson(null, {
#                 onEachFeature: geo_json_d645fcda39d4bea06e1fee89f2ac38f2_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_d645fcda39d4bea06e1fee89f2ac38f2_add (data) {
#             geo_json_d645fcda39d4bea06e1fee89f2ac38f2
#                 .addData(data);
#         }
#             geo_json_d645fcda39d4bea06e1fee89f2ac38f2_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &quot;peps:isN

# %% [markdown]
# All the products not withing the read area are correctly filtered out by [FilterOverlap](../../plugins_reference/generated/eodag.plugins.crunch.filter_overlap.FilterOverlap.rst#eodag.plugins.crunch.filter_overlap.FilterOverlap). A new geometry is created in order to test the next parameter `intersects`.

# %%
from shapely.geometry import Polygon
shifted_geom = Polygon([[4, 44], [9, 44], [9, 48], [4, 48], [4, 48]])

# %%
filtered_products = search_results.crunch(
    FilterOverlap(dict(intersects=True)),
    geometry=shifted_geom
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the geometry filter.")
# Out:
# 31 products were filtered out by the geometry filter.

# %%
fmap = create_search_result_map(search_results, shifted_geom)
# Create a layer that represents the filtered products in green
folium.GeoJson(
    filtered_products,
    style_function=lambda x: dict(color="green")
).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c75579ef97b0f32704da13fc622fc88f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c75579ef97b0f32704da13fc622fc88f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c75579ef97b0f32704da13fc622fc88f = L.map(
#                 &quot;map_c75579ef97b0f32704da13fc622fc88f&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_304d22f06802282d68e7d25e0edb8cd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_304d22f06802282d68e7d25e0edb8cd7.addTo(map_c75579ef97b0f32704da13fc622fc88f);
#
#
#         function geo_json_e7257f8236cf6cac67319c160c6d6787_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_e7257f8236cf6cac67319c160c6d6787_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e7257f8236cf6cac67319c160c6d6787 = L.geoJson(null, {
#                 onEachFeature: geo_json_e7257f8236cf6cac67319c160c6d6787_onEachFeature,
#
#                 style: geo_json_e7257f8236cf6cac67319c160c6d6787_styler,
#             ...{
# }
#         });
#
#         function geo_json_e7257f8236cf6cac67319c160c6d6787_add (data) {
#             geo_json_e7257f8236cf6cac67319c160c6d6787
#                 .addData(data);
#         }
#             geo_json_e7257f8236cf6cac67319c160c6d6787_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[4.0, 44.0], [9.0, 44.0], [9.0, 48.0], [4.0, 48.0], [4.0, 48.0], [4.0, 44.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_e7257f8236cf6cac67319c160c6d6787.addTo(map_c75579ef97b0f32704da13fc622fc88f);
#
#
#
#         function geo_json_d6964b981a6bf95ff425111bf0e019c4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d6964b981a6bf95ff425111bf0e019c4 = L.geoJson(null, {
#                 onEachFeature: geo_json_d6964b981a6bf95ff425111bf0e019c4_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_d6964b981a6bf95ff425111bf0e019c4_add (data) {
#             geo_json_d6964b981a6bf95ff425111bf0e019c4
#                 .addData(data);
#         }
#             geo_json_d6964b981a6bf95ff425111bf0e019c4_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &

# %% [markdown]
# The products that do not intersect with the red area are correctly filtered out. Finally another new geometry is created to test the parameter `contains`.

# %%
small_geom = Polygon([[3.2, 44.4], [3.7, 44.4], [3.7, 44.9], [3.2, 44.9], [3.2, 44.4]])

# %%
filtered_products = search_results.crunch(
    FilterOverlap(dict(contains=True)),
    geometry=small_geom
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the geometry filter.")
# Out:
# 49 products were filtered out by the geometry filter.

# %%
fmap = create_search_result_map(search_results, small_geom)
# Create a layer that represents the filtered products in green
folium.GeoJson(
    filtered_products,
    style_function=lambda x: dict(color="green")
).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d41a1393a449e951d6c15e31acc28072 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d41a1393a449e951d6c15e31acc28072&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d41a1393a449e951d6c15e31acc28072 = L.map(
#                 &quot;map_d41a1393a449e951d6c15e31acc28072&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d60c4f17ecb91c304af76a7c0b933b5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d60c4f17ecb91c304af76a7c0b933b5a.addTo(map_d41a1393a449e951d6c15e31acc28072);
#
#
#         function geo_json_c09b353e9aaf48fa9f500ea703a81209_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_c09b353e9aaf48fa9f500ea703a81209_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c09b353e9aaf48fa9f500ea703a81209 = L.geoJson(null, {
#                 onEachFeature: geo_json_c09b353e9aaf48fa9f500ea703a81209_onEachFeature,
#
#                 style: geo_json_c09b353e9aaf48fa9f500ea703a81209_styler,
#             ...{
# }
#         });
#
#         function geo_json_c09b353e9aaf48fa9f500ea703a81209_add (data) {
#             geo_json_c09b353e9aaf48fa9f500ea703a81209
#                 .addData(data);
#         }
#             geo_json_c09b353e9aaf48fa9f500ea703a81209_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[3.2, 44.4], [3.7, 44.4], [3.7, 44.9], [3.2, 44.9], [3.2, 44.4]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c09b353e9aaf48fa9f500ea703a81209.addTo(map_d41a1393a449e951d6c15e31acc28072);
#
#
#
#         function geo_json_bf4b65b9134d36fc62a3d585b1de1379_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bf4b65b9134d36fc62a3d585b1de1379 = L.geoJson(null, {
#                 onEachFeature: geo_json_bf4b65b9134d36fc62a3d585b1de1379_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_bf4b65b9134d36fc62a3d585b1de1379_add (data) {
#             geo_json_bf4b65b9134d36fc62a3d585b1de1379
#                 .addData(data);
#         }
#             geo_json_bf4b65b9134d36fc62a3d585b1de1379_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &quot;peps:isN

# %% [markdown]
# The only product preserved is the one that contains the red area.

# %% [markdown]
# ## Filter by property

# %% [markdown]
# [FilterProperty](../../plugins_reference/generated/eodag.plugins.crunch.filter_property.FilterProperty.rst#eodag.plugins.crunch.filter_property.FilterProperty) evaluates a single property of all the products against a value (e.g. cloud cover less than 10). The dictionary it requires should contain:
#
# * A single property name from [EOProduct](../../api_reference/eoproduct.rst#eodag.api.product._product.EOProduct)`.properties` and its tested value, e.g. `{"eo:cloud_cover": 10}` or `{"order:status": "succeeded"}`
# * One (optional) operator among `lt` (<), `le` (<=), `eq` (==), `ne` (!=), `ge` (>=), `gt` (>). `eq` by default.
#
# > This cruncher can also be called directly using [SearchResult.filter_property()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.filter_property).

# %%
from eodag.crunch import FilterProperty

# %%
filtered_products = search_results.crunch(
    FilterProperty({"eo:cloud_cover":10, "operator": "lt"})
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the property filter.")
# Out:
# 23 products were filtered out by the property filter.

# %% [markdown]
# List comprehensions over a collection of EO products are useful to quickly extract their properties, and here to check that the filter correctly filtered the products.

# %%
all([p.properties["eo:cloud_cover"] < 10 for p in filtered_products])
# Out:
# True

# %% [markdown]
# ## Filter for online products

# %% [markdown]
# Sometimes you may want to avoid ordering orderable products, and only download the one marked succeeded.
#
# You can already filter for online products using [FilterProperty](../../plugins_reference/generated/eodag.plugins.crunch.filter_property.FilterProperty.rst#eodag.plugins.crunch.filter_property.FilterProperty) like this:

# %%
filtered_products = search_results.crunch(
    FilterProperty({"order:status": "succeeded", "operator": "eq"})
)
print(f"{len(filtered_products)} products are online.")
# Out:
# 50 products are online.

# %% [markdown]
# While this code do the job, it is quite verbose. The better way is to use [SearchResult.filter_online()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.filter_online).

# %%
filtered_products = search_results.filter_online()
print(f"{len(filtered_products)} products are online.")
# Out:
# 50 products are online.

# %% [markdown]
# ## Filter the latest products intersecting a geometry

# %% [markdown]
# [FilterLatestIntersect](../../plugins_reference/generated/eodag.plugins.crunch.filter_latest_intersect.FilterLatestIntersect.rst#eodag.plugins.crunch.filter_latest_intersect.FilterLatestIntersect) does the following:
#
# 1. it sorts the products by date, from the newest to the oldest
# 2. it filters out products that do not intersect with a requested geometry (a dictionary bounding box)
# 3. it stops early if the requested geometry is 100% covered by the products, if not, it returns the result of 2.
#
# This results in getting the most recent products that intersect (or completely cover) a given geometry.
#
# > This cruncher can also be called directly using [SearchResult.filter_latest_intersect()](../../api_reference/searchresult.rst#eodag.api.search_result.SearchResult.filter_latest_intersect).

# %%
from eodag.crunch import FilterLatestIntersect

# %%
filtered_products = search_results.crunch(
    FilterLatestIntersect({}),
    geometry=original_search_geometry
)
print(f"{len(search_results) - len(filtered_products)} products were filtered out by the property filter.")
# Out:
# 14 products were filtered out by the property filter.

# %%
from shapely import geometry

fmap = create_search_result_map(search_results, search_geometry)
# Create a layer that represents the filtered products in green
folium.GeoJson(
    filtered_products,
    style_function=lambda x: dict(color="green")
).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b245cba62e983e6a477ab91072dab96e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b245cba62e983e6a477ab91072dab96e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b245cba62e983e6a477ab91072dab96e = L.map(
#                 &quot;map_b245cba62e983e6a477ab91072dab96e&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ef93b5c8363d07153904b85b3f32698 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ef93b5c8363d07153904b85b3f32698.addTo(map_b245cba62e983e6a477ab91072dab96e);
#
#
#         function geo_json_7bdc93cbaefad1897e65c045029fb6ce_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_7bdc93cbaefad1897e65c045029fb6ce_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7bdc93cbaefad1897e65c045029fb6ce = L.geoJson(null, {
#                 onEachFeature: geo_json_7bdc93cbaefad1897e65c045029fb6ce_onEachFeature,
#
#                 style: geo_json_7bdc93cbaefad1897e65c045029fb6ce_styler,
#             ...{
# }
#         });
#
#         function geo_json_7bdc93cbaefad1897e65c045029fb6ce_add (data) {
#             geo_json_7bdc93cbaefad1897e65c045029fb6ce
#                 .addData(data);
#         }
#             geo_json_7bdc93cbaefad1897e65c045029fb6ce_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.0, 45.0], [5.0, 47.0], [1.0, 47.0], [1.0, 45.0], [5.0, 45.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_7bdc93cbaefad1897e65c045029fb6ce.addTo(map_b245cba62e983e6a477ab91072dab96e);
#
#
#
#         function geo_json_2991fe7908b8ef162c817606ebbd102c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2991fe7908b8ef162c817606ebbd102c = L.geoJson(null, {
#                 onEachFeature: geo_json_2991fe7908b8ef162c817606ebbd102c_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_2991fe7908b8ef162c817606ebbd102c_add (data) {
#             geo_json_2991fe7908b8ef162c817606ebbd102c
#                 .addData(data);
#         }
#             geo_json_2991fe7908b8ef162c817606ebbd102c_add({&quot;features&quot;: [{&quot;assets&quot;: {}, &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.706254, 45.933497], [5.755585, 46.920536], [5.258958, 46.929367], [5.24191, 46.881764], [5.189442, 46.73517], [5.137079, 46.58859], [5.085122, 46.442024], [5.033679, 46.295452], [4.982568, 46.148896], [4.931761, 46.002347], [4.912627, 45.947381], [5.706254, 45.933497]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;S2ST&quot;, &quot;created&quot;: &quot;2023-07-03T09:57:22.907Z&quot;, &quot;description&quot;: null, &quot;end_datetime&quot;: &quot;2021-03-30T10:30:21.024Z&quot;, &quot;eo:cloud_cover&quot;: 0, &quot;eo:snow_cover&quot;: null, &quot;eodag:collection&quot;: &quot;S2_MSI_L1C&quot;, &quot;eodag:download_link&quot;: &quot;https://peps.cnes.fr/resto/collections/S2ST/01a70fba-6fda-50b2-9749-256f579270c5/download&quot;, &quot;eodag:provider&quot;: &quot;peps&quot;, &quot;eodag:quicklook&quot;: &quot;https://peps.cnes.fr/quicklook/2021/03/30/S2A/S2A_MSIL1C_20210330T103021_N0500_R108_T31TFM_20230523T215656_quicklook.jpg&quot;, &quot;eodag:search_intersection&quot;: {&quot;coordinates&quot;: [[[4.912627, 45.947381], [4.931761, 46.002347], [4.982568, 46.148896], [5.0, 46.198881], [5.0, 45.945852], [4.912627, 45.947381]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;eodag:thumbnail&quot;: null, &quot;grid:code&quot;: &quot;MGRS-31TFM&quot;, &quot;gsd&quot;: null, &quot;instruments&quot;: [&quot;MSI&quot;], &quot;keywords&quot;: [&quot;Europe&quot;, &quot;France&quot;, &quot;Rh\u00f4ne-Alpes&quot;, &quot;Ain&quot;, &quot;Franche-Comt\u00e9&quot;, &quot;Jura&quot;, &quot;Bourgogne&quot;, &quot;Sa\u00f4ne-et-Loire&quot;, &quot;Northern&quot;, &quot;Spring&quot;, &quot;S2ST&quot;, &quot;S2MSI1C&quot;, &quot;LEVEL1C&quot;, &quot;s2A&quot;, &quot;msi&quot;, &quot;INS-NOBS&quot;, &quot;Descending&quot;, &quot;Nominal&quot;, &quot;2021&quot;, &quot;March&quot;, &quot;30&quot;], &quot;order:status&quot;: &quot;succeeded&quot;, &quot;peps:bareSoil&quot;: null, &quot;peps:bucket&quot;: &quot;sentinel2-l1c&quot;, &quot;peps:highProbaClouds&quot;: null, &quot;peps:isN

# %% [markdown]
# The map shows that the area is fully covered by products. The filtered products are indeed the most recent ones.

# %%
[p.properties["start_datetime"] for p in filtered_products][::10]
# Out:
# ['2021-03-30T10:30:21.024Z',
#  '2021-03-28T10:36:29.024Z',
#  '2021-03-28T10:36:29.024Z',
#  '2021-03-26T10:50:31.024Z']
