# %% [markdown]
# # Providers and products
#
# This section introduces the main features related to providers and collections available in eodag.
# You will learn how to:
# - [List available providers](#Providers-available)
# - [List available collections](#collections-available)
# - [Combine both methods](#Combine-these-two-methods)
# - [Discover collections dynamically](#collections-discovery)
#
# Only providers that do not need authentication for search will be listed here. This notebook is executed in CI/CD without providers credentials, and EODAG hides providers needing authentication for search that do not have credentials set.

# %%
from eodag import EODataAccessGateway, setup_logging

setup_logging(2)

dag = EODataAccessGateway()
# Out:
# 2025-11-06 15:58:49,857 eodag.config                     [INFO    ] Loading user configuration from: /home/anesson/.config/eodag/eodag.yml
# 2025-11-06 15:58:49,883 eodag.core                       [INFO    ] geodes_s3: provider needing auth for search has been pruned because no credentials could be found
# 2025-11-06 15:58:49,885 eodag.core                       [INFO    ] Locations configuration loaded from /home/anesson/.config/eodag/locations.yml

# %% [markdown]
# ## Providers available

# %% [markdown]
# The method [available_providers()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.available_providers) returns a list of the pre-configured providers.

# %%
available_providers = dag.available_providers()
available_providers
# Out:
# ['creodias_s3',
#  'planetary_computer',
#  'peps',
#  'aws_eos',
#  'cop_ads',
#  'cop_cds',
#  'cop_dataspace',
#  'cop_ewds',
#  'cop_ghsl',
#  'cop_marine',
#  'creodias',
#  'dedl',
#  'dedt_lumi',
#  'dedt_mn5',
#  'earth_search',
#  'earth_search_gcs',
#  'ecmwf',
#  'eumetsat_ds',
#  'fedeo_ceda',
#  'geodes',
#  'geodes_s3',
#  'hydroweb_next',
#  'meteoblue',
#  'sara',
#  'usgs',
#  'usgs_satapi_aws',
#  'wekeo_cmems',
#  'wekeo_ecmwf',
#  'wekeo_main']

# %%
print(f"eodag has {len(available_providers)} providers already configured.")
# Out:
# eodag has 28 providers already configured.

# %% [markdown]
# It can take a collection as an argument and will return the providers known to `eodag` that offer this product.

# %%
dag.available_providers("S2_MSI_L1C")
# Out:
# ['peps',
#  'aws_eos',
#  'cop_dataspace',
#  'creodias',
#  'creodias_s3',
#  'dedl',
#  'earth_search',
#  'earth_search_gcs',
#  'geodes',
#  'geodes_s3',
#  'sara',
#  'usgs',
#  'wekeo_main']

# %% [markdown]
# <div class="alert alert-warning">
#
# Note
#
# If a provider is configured to need authentication for search, and has no credentials set, it will be pruned on EODAG initialization, and will not appear in available providers list.
#
# </div>

# %% [markdown]
# ## Collections available

# %% [markdown]
# The method [list_collections()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.list_collections) returns a [CollectionsList](../../api_reference/collection.rst#eodag.api.collection.CollectionsList) instance that represents `eodag`'s internal collection catalog if used with `fetch_providers=False`. It will fetch providers for new collections and return an extended list if used with `fetch_providers=True` (default behavior).
#
# <div class="alert alert-warning">
# [Breaking change](../../breaking_changes.rst) in v4.0.0
#
# [list_collections()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.list_collections) returns a [CollectionsList](../../api_reference/collection.rst#eodag.api.collection.CollectionsList) instance, which is a list of [Collection](../../api_reference/collection.rst#eodag.api.collection.Collection) instances, instead of a list of dictionaries.
#
# </div>

# %%
internal_catalog = dag.list_collections(fetch_providers=False)
print(f"EODAG has {len(internal_catalog)} collections stored in its internal catalog.")
# Out:
# EODAG has 308 collections stored in its internal catalog.

# %%
extended_catalog = dag.list_collections()
print(f"EODAG has {len(extended_catalog)} collections stored in its extended catalog, after having fetched providers.")
# Out:
# 2025-11-06 15:59:03,185 eodag.config                     [INFO    ] Fetching external collections from https://cs-si.github.io/eodag/eodag/resources/ext_collections.json
# 2025-11-06 15:59:04,319 eodag.search.qssearch            [INFO    ] Fetching collections: https://hydroweb.next.theia-land.fr/api/v1/rs-catalog/stac/search/../collections
# 2025-11-06 15:59:07,458 eodag.search.qssearch            [INFO    ] Fetching collections: https://hda.data.destination-earth.eu/stac/collections
# EODAG has 1445 collections stored in its extended catalog, after having fetched providers.

# %% [markdown]
# When providers are fetched for new collections, `eodag`'s collections configuration is updated in `EODataAccessGateway` instance. Extended collections list is then returned independantly of `fetch_providers` option in [list_collections()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.list_collections):

# %%
called_again_catalog = dag.list_collections(fetch_providers=False)
print(f"list_collections() keeps returning {len(called_again_catalog)} collections.")
# Out:
# list_collections() keeps returning 1445 collections.

# %%
internal_catalog
# Out:
# CollectionsList([Collection("AERIS_IAGOS"), Collection("AG_ERA5"), Collection("CAMS_EAC4"), Collection("CAMS_EAC4_MONTHLY"), Collection("CAMS_EU_AIR_QUALITY_FORECAST"), Collection("CAMS_EU_AIR_QUALITY_RE"), Collection("CAMS_GAC_FORECAST"), Collection("CAMS_GFE_GFAS"), Collection("CAMS_GLOBAL_EMISSIONS"), Collection("CAMS_GREENHOUSE_EGG4"), Collection("CAMS_GREENHOUSE_EGG4_MONTHLY"), Collection("CAMS_GREENHOUSE_INVERSION"), Collection("CAMS_GRF"), Collection("CAMS_GRF_AUX"), Collection("CAMS_SOLAR_RADIATION"), Collection("CBERS4_AWFI_L2"), Collection("CBERS4_AWFI_L4"), Collection("CBERS4_MUX_L2"), Collection("CBERS4_MUX_L4"), Collection("CBERS4_PAN10M_L2"), Collection("CBERS4_PAN10M_L4"), Collection("CBERS4_PAN5M_L2"), Collection("CBERS4_PAN5M_L4"), Collection("CLMS_CORINE"), Collection("CLMS_GLO_DMP_333M"), Collection("CLMS_GLO_FAPAR_333M"), Collection("CLMS_GLO_FCOVER_333M"), Collection("CLMS_GLO_GDMP_333M"), Collection("CLMS_GLO_LAI_333M"), Collection("CLMS_GLO_NDVI_1KM_LTS"), Collection("CLMS_GLO_NDVI_333M"), Collection("CMIP6_CLIMATE_PROJECTIONS"), Collection("COP_DEM_GLO30_DGED"), Collection("COP_DEM_GLO30_DTED"), Collection("COP_DEM_GLO90_DGED"), Collection("COP_DEM_GLO90_DTED"), Collection("DT_CLIMATE_ADAPTATION"), Collection("DT_CLIMATE_G1_CMIP6_HIST_ICON_R1"), Collection("DT_CLIMATE_G1_CMIP6_HIST_IFS_FESOM_R1"), Collection("DT_CLIMATE_G1_CMIP6_HIST_IFS_NEMO_R1"), Collection("DT_CLIMATE_G1_HIGHRESMIP_CONT_IFS_FESOM_R1"), Collection("DT_CLIMATE_G1_HIGHRESMIP_CONT_IFS_NEMO_R1"), Collection("DT_CLIMATE_G1_SCENARIOMIP_SSP3_7_0_ICON_R1"), Collection("DT_CLIMATE_G1_SCENARIOMIP_SSP3_7_0_IFS_FESOM_R1"), Collection("DT_CLIMATE_G1_SCENARIOMIP_SSP3_7_0_IFS_FESOM_R2"), Collection("DT_CLIMATE_G1_SCENARIOMIP_SSP3_7_0_IFS_NEMO_R1"), Collection("DT_CLIMATE_G1_STORY_NUDGING_CONT_IFS_FESOM_R1"), Collection("DT_CLIMATE_G1_STORY_NUDGING_HIST_IFS_FESOM_R1"), Collection("DT_CLIMATE_G1_STORY_NUDGING_TPLUS2_0K_IFS_FESOM_R1"), Collection("DT_EXTREMES"), Collection("EEA_DAILY_VI"), Collection("EEA_HRL_TCF"), Collection("EFAS_FORECAST"), Collection("EFAS_HISTORICAL"), Collection("EFAS_REFORECAST"), Collection("EFAS_SEASONAL"), Collection("EFAS_SEASONAL_REFORECAST"), Collection("ERA5_LAND"), Collection("ERA5_LAND_MONTHLY"), Collection("ERA5_PL"), Collection("ERA5_PL_MONTHLY"), Collection("ERA5_SL"), Collection("ERA5_SL_MONTHLY"), Collection("EUSTAT_AVAILABLE_BEDS_HOSPITALS_NUTS2"), Collection("EUSTAT_BATHING_SITES_WATER_QUALITY"), Collection("EUSTAT_GREENHOUSE_GAS_EMISSION_AGRICULTURE"), Collection("EUSTAT_POP_AGE_GROUP_SEX_NUTS3"), Collection("EUSTAT_POP_AGE_SEX_NUTS2"), Collection("EUSTAT_POP_CHANGE_DEMO_BALANCE_CRUDE_RATES_NUTS3"), Collection("EUSTAT_POP_DENSITY_NUTS3"), Collection("EUSTAT_SHARE_ENERGY_FROM_RENEWABLE"), Collection("EUSTAT_SOIL_SEALING_INDEX"), Collection("EUSTAT_SURFACE_TERRESTRIAL_PROTECTED_AREAS"), Collection("FIRE_HISTORICAL"), Collection("FIRE_SEASONAL"), Collection("GLACIERS_DIST_RANDOLPH"), Collection("GLOFAS_FORECAST"), Collection("GLOFAS_HISTORICAL"), Collection("GLOFAS_REFORECAST"), Collection("GLOFAS_SEASONAL"), Collection("GLOFAS_SEASONAL_REFORECAST"), Collection("GRIDDED_GLACIERS_MASS_CHANGE"), Collection("GSW_CHANGE"), Collection("GSW_EXTENT"), Collection("GSW_OCCURRENCE"), Collection("GSW_RECURRENCE"), Collection("GSW_SEASONALITY"), Collection("GSW_TRANSITIONS"), Collection("HIRS_FDR_1_MULTI"), Collection("ISIMIP_CLIMATE_FORCING_ISIMIP3B"), Collection("ISIMIP_SOCIO_ECONOMIC_FORCING_ISIMIP3B"), Collection("L8_OLI_TIRS_C1L1"), Collection("LANDSAT_C2L1"), Collection("LANDSAT_C2L2"), Collection("LANDSAT_C2L2ALB_BT"), Collection("LANDSAT_C2L2ALB_SR"), Collection("LANDSAT_C2L2ALB_ST"), Collection("LANDSAT_C2L2ALB_TA"), Collection("LANDSAT_C2L2_SR"), Collection("LANDSAT_C2L2_ST"), Collection("LANDSAT_ETM_C1"), Collection("LANDSAT_ETM_C2L1"), Collection("LANDSAT_ETM_C2L2"), Collection("LANDSAT_TM_C1"), Collection("LANDSAT_TM_C2L1"), Collection("LANDSAT_TM_C2L2"), Collection("METOP_AMSU_L1"), Collection("METOP_ASCSZF1B"), ...

# %%
extended_catalog = dag.list_collections()
print(f"EODAG has {len(extended_catalog)} collections stored in its extended catalog, after having fetched providers.")
# Out:
# EODAG has 1445 collections stored in its extended catalog, after having fetched providers.

# %% [markdown]
# When providers are fetched for new collections, `eodag`'s collections configuration is updated in `EODataAccessGateway` instance. Extended collections list is then returned independantly of `fetch_providers` option in [list_collections()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.list_collections):

# %%
called_again_catalog = dag.list_collections(fetch_providers=False)
print(f"list_collections() keeps returning {len(called_again_catalog)} collections.")
# Out:
# list_collections() keeps returning 1445 collections.

# %%
internal_catalog[0]
# Out:
# Collection(id='AERIS_IAGOS', title='In-service Aircraft for a Global Observing System', extent=Extent(spatial=SpatialExtent(bbox=[(-180.0, -90.0, 180.0, 90.0)]), temporal=TimeInterval(interval=[[datetime.datetime(1994, 8, 1, 0, 0, tzinfo=datetime.timezone.utc), None]])), processing_level='L2', instruments=['IAGOS-CORE', 'IAGOS-MOZAIC', 'IAGOS-CARIBIC'], eodag_sensor_type='ATMOSPHERIC', keywords=['AERIS', 'AIRCRAFT', 'ATMOSPHERIC', 'IAGOS', 'L2'], license='other', description='The mission of IAGOS is to provide high quality data throughout the tropopshere\nand lower stratosphere, and scientific expertise to understand the evolution of\natmospheric composition, air quality, and climate.\n')

# %%
internal_catalog[0].description
# Out:
# 'The mission of IAGOS is to provide high quality data throughout the tropopshere\nand lower stratosphere, and scientific expertise to understand the evolution of\natmospheric composition, air quality, and climate.\n'

# %% [markdown]
# The method can take a provider name as an argument and will return the collections known to `eodag` that are offered by this provider.

# %%
dag.list_collections("peps")
# Out:
# CollectionsList([Collection("S1_SAR_GRD"), Collection("S1_SAR_OCN"), Collection("S1_SAR_SLC"), Collection("S2_MSI_L1C")])

# %% [markdown]
# As seen above, each collection resulting from [list_collections()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.list_collections) is a [Collection](../../api_reference/collection.rst#eodag.api.collection.Collection) instance. That make [search()](./3_search.ipynb#Search-from-Collection) and [list_queryables()](./4_queryables.ipynb#Queryables-from-Collection) methods available from them.

# %% [markdown]
# ## Combine these two methods

# %% [markdown]
# These two methods can be combined to find which collection is the most common in `eodag`'s catalog among all the providers.

# %%
availability_per_product = []
products_id = [p.id for p in internal_catalog]
for product in products_id:
    providers = dag.available_providers(product)
    availability_per_product.append((product, len(providers)))
availability_per_product = sorted(availability_per_product, key=lambda x: x[1], reverse=True)
most_common_p_type, nb_providers = availability_per_product[0]
print(f"The most common collection is '{most_common_p_type}' with {nb_providers} providers offering it.")
# Out:
# The most common collection is 'S2_MSI_L1C' with 12 providers offering it.

# %% [markdown]
# These can be also used to find out which provider (as configured by `eodag`) offers the hights number of different collections.

# %%
availability_per_provider = []
for provider in dag.available_providers():
    provider_products_id = [
        p.id
        for p in dag.list_collections(provider, fetch_providers=False)
    ]
    availability_per_provider.append(
        (provider, len(provider_products_id))
    )
availability_per_provider = sorted(availability_per_provider, key=lambda x: x[1], reverse=True)
provider, nb_p_types = availability_per_provider[0]
print(f"The provider with the largest number of collections is '{provider}' with {nb_p_types}.")
# Out:
# The provider with the largest number of collections is 'dedl' with 376.

# %% [markdown]
# ## Collections discovery

# %% [markdown]
# EODAG comes with a large list of pre-configured collections. Some others are available from providers catalogs but will not be configured, or are not yet configured in EODAG.
#
# Some providers, like STAC providers, come in EODAG with a configuration describing how to discover these not-already-configured collections.
#
# With the method [discover_collections()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.discover_collections)
# or CLI command [eodag discover](../../cli_user_guide.rst) we can obtain a JSON configuration file that will be used as *EODAG
# external collections configuration file*.
#
# In EODAG, the discovered *EODAG external collections configuration file* can be set to:
#
# * a file automatically built from github actions and stored in [eodag/resources/ext_collections.json](https://cs-si.github.io/eodag/eodag/resources/ext_collections.json) (default settings)
# * a custom remote or local file by setting its path in `EODAG_EXT_COLLECTIONS_CFG_FILE` environment variable (if the file is not readable, only user-modified providers will be fetched).
#
# Then, when listing collections using [list_collections(fetch_providers=True)](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.list_collections), EODAG will first read the content of the *EODAG external collections configuration file* using [fetch_collections_list()](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway.fetch_collections_list)
# then update [EODataAccessGateway](../../api_reference/core.rst#eodag.api.core.EODataAccessGateway) instance collections configuration, if needed.
#
# The obtained collections list will contain both pre-configured and discovered collections.
#
# ![Fetch collections schema](../../_static/eodag_fetch_collections.png "Fetch collections schema")
